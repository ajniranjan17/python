# %%
#list in python
#list is an ordered and changeable collection that can store multiplke values
marks = [80, 90, 75, 85]

print(marks)
# Out:
# [80, 90, 75, 85]

# %%
#accessing elements in a list
marks = [80, 90, 75, 85]

print(marks[0])
print(marks[1])
print(marks[3])
# Out:
# 80
# 90
# 85

# %%
#change elements in a list
marks = [80, 90, 75]

marks[1] = 95

print(marks)
# Out:
# [80, 95, 75]

# %%
#add elements to a list
marks = [80, 90, 75]

marks.append(85)

print(marks0)
# Out:
# [80, 90, 75, 85]
